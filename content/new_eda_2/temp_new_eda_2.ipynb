# %% [markdown]
# All right, welcome everyone.
# 0:1919 secondsWelcome back. Thanks all for coming out even though it might rain today. So, we're going to continue our EDA series
# 0:2626 secondsuh today and into next week. Uh some announcements before we start. So prerecat quiz logistics are on ed.
# 0:3232 secondsHopefully you've all you know taken a look had a chance to uh practice. Um the testing window is going to be next
# 0:4040 secondsTuesday to Thursday. So make sure you sign up for a slot. All the information is there on ED. Sign up ASAP. If you want a particular time, you don't want to have a conflict, please sign up now.
# 0:5050 secondsWe have limited availability to change things after the fact. Um homework zero is due tomorrow, so hopefully you're close to done. Homework one will be
# 0:5858 secondsreleased tomorrow. Normally we'll be releasing homework on Thursdays. Um this one making a few tweaks again because we're changing up the beginning of the class. So that'll be out tomorrow. Uh if
# 1:071 minute, 7 secondsyou need a refresher on SQL, we have an ed post which links to some helpful material that I posted. There's also a very helpful link from um from course
# 1:151 minute, 15 secondsstaff on some additional resources in the comments. This is especially important if you've taken a class other than 61A or 88C where you might not have covered that material before.
# 1:261 minute, 26 secondsUm, as I mentioned last week, I'll have uh a bunch of signup slots open for one-on-one chats. So, if you want a 15-minute slot, please feel free to sign up. There's a a link from the slides.
# 1:361 minute, 36 secondsUm, priority for slots before uh October 16th goes to anybody graduating relatively soon. That is on or before
# 1:441 minute, 44 secondsspring 2028. So, if you're graduating after that, um you're welcome to take a slot. Just please take one, you know, the week after this or two weeks after
# 1:531 minute, 53 secondssince I'm gone the next week. Okay. Um, with that, I'll hand it over to Minashi to talk about Academia.
# 2:022 minutes, 2 secondsHi everyone. Uh, I'm really excited to announce that Data 100 is using a new course platform this semester called Academia. So, Academia is a video
# 2:112 minutes, 11 secondsintelligence platform that basically lets you interact with your lectures. So, our core feature is our Q&A chatbot.
# 2:192 minutes, 19 secondsSo, it lets you ask questions while you watch live or recorded lectures. Uh the system is contextaware meaning that you can ask a question like uh what did he
# 2:272 minutes, 27 secondsjust say or like what's happening right now what's on screen and our chatbot will understand uh pull the context from the audio and the video to answer your questions.
# 2:372 minutes, 37 secondsUh we have a few other features like a self quiz tab. So any point in the lecture you can quiz yourself and it's going to create a multiple choice
# 2:452 minutes, 45 secondsquestion for you to review. Uh we have a topics tab which lets you navigate to uh different moments in the lecture. And we
# 2:522 minutes, 52 secondsalso have a search tab which lets you kind of search up specific topics or visuals just any moment you want to look for from the entire course or maybe from
# 3:003 minutesthe specific lecture that you're watching. So hopefully this helps you navigate um your course a little bit better. Uh we have a few other features that we're going to be rolling out this
# 3:083 minutes, 8 secondssemester. Um oh sorry about that. And so the link is linked at the top over here.
# 3:153 minutes, 15 secondsIt's also going to be linked on the data 100 course website. So all your lectures will be on academia. You can just log in as a student and you should be able to
# 3:223 minutes, 22 secondssee it immediately. Um we're open to any feedback you might have for us throughout the semester. We have a contact form. But yeah, we're really excited for you guys to use academia.
# 3:303 minutes, 30 secondsThanks so much.
# 3:383 minutes, 38 secondsAll right. So uh definitely encourage you to check out Academia. every lecture, you know, in addition to having the slides, any demo notebooks, YouTube recording will also now have a link to
# 3:463 minutes, 46 secondsthe academia recording. So, you can always access it from there, too. All right. So, where were we? We were
# 3:533 minutes, 53 secondstalking about this uh case study of identifying five schools that defy typical patterns of application,
# 4:014 minutes, 1 secondadmission, and attendance, right? And we kind of decided on these four key questions that we're going to focus in
# 4:074 minutes, 7 secondson for uh the start of our exploratory data analysis. Right? We started by understanding the question of do we
# 4:144 minutes, 14 secondstrust the data? Does our data actually correspond to truth in the real world?
# 4:194 minutes, 19 secondsAnd we saw the answer was like kind of sometimes yes and in some ways maybe not as much. But as long as we are honest about the ways that it doesn't, we
# 4:284 minutes, 28 secondsshould proceed forward, right? and communicate clearly but use the data that we have to make interesting meaningful conclusions. We talked about
# 4:364 minutes, 36 secondsextremes, right? Understanding the like minima, maxima, uh the schools with the highest application rate, maybe the lowest application rate. And then we
# 4:454 minutes, 45 secondsleft off last time in the middle of understanding distributions and variation. Right? If we think about like application rate, which is the one we focused on, but also we could look at
# 4:534 minutes, 53 secondsadmission attendance rates. We look at application rate across different schools. Different schools have different application rates, right?
# 5:005 minutesWhich kind of makes sense. So if different schools have different application rates, why why are those differences there? What are those differences? How spread out are they?
# 5:095 minutes, 9 secondsRight? Are they all like, you know, close to 20% and then there's a few much higher, much lower? Are they kind of spread out? What are those differences
# 5:175 minutes, 17 secondsand why are they there? And then last but not least is are any school characteristics related to the rates
# 5:255 minutes, 25 secondsabove, the three rates, right? And so that's going to get into something called correlation.
# 5:315 minutes, 31 secondsSo, we also spent a bunch of time building up our knowledge of polers and SQL to analyze data, right? So, here's like a big table, but don't be alarmed.
# 5:415 minutes, 41 secondsThere's nothing new here, right? This is all stuff you've seen over almost all stuff you've seen over the last uh week,
# 5:495 minutes, 49 secondsright? And we said we're going to focus primarily on these English descriptions, right? which are the most important thing being able to clearly articulate what you want to do with your data.
# 6:016 minutes, 1 secondRight? We talked about how to load in the data, how to select or choose certain columns, right? Using uh in
# 6:086 minutes, 8 secondspolers that's like my dataf frame select, right? And we give column names using plall
# 6:156 minutes, 15 secondsand the name of the column. And if we're just selecting, we saw we can get away by just typing in the name of the column. Little shortcut. uh if we have a
# 6:246 minutes, 24 secondsparticular column that we want to pull out just the one column then we use these brackets same way we do with the Python dictionary and we can ask that
# 6:326 minutes, 32 secondsone column for its minimum maximum mean standard deviation and so on we saw the ability to sort which is something we
# 6:396 minutes, 39 secondsused a whole bunch last class right we says sort you give it the name of the column whether it's descending or
# 6:466 minutes, 46 secondsascending and we saw we can count the number of rows by looking at the len for the shape attribute which is like a
# 6:546 minutes, 54 secondstupal of number of rows number of columns and then we uh towards the end
# 7:007 minutesof class we added a new column onto our table right how do we add a new column well first we create a new data frame
# 7:087 minutes, 8 secondsthat has that column right by using the width columns attribute and
# 7:157 minutes, 15 secondswhy is this not working all right um all right for some reason My iPad's not working properly
# 7:227 minutes, 22 secondstoday. But uh the way this is going to work is we're going to use width columns, right? And width columns,
# 7:307 minutes, 30 secondsright, takes in an argument that is the column or if there's more than one, the columns we want to add each as an argument with a comma. And we can give
# 7:397 minutes, 39 secondsit a name one of two ways. The way we spent most time last time is by saying column name. This is going to be app
# 7:467 minutes, 46 secondsequals and then the stuff that's going to go in that column. And how do we do this stuff? Well, this is just an application, right? We take the number
# 7:547 minutes, 54 secondsof people who applied, divide by the number of 12th graders. How do we get the number of people who applied? We take the applied column, plcall applied.
# 8:038 minutes, 3 secondsHow do we get the number of 12th graders? The grade 12 column, pl grade 12, and then use a division operator.
# 8:108 minutes, 10 secondsAnother way we can do this is by constructing the column, right, by saying applied divided by grade 12,
# 8:188 minutes, 18 secondsright? And that gives us a column that doesn't have a name. And then we can use this handy dandy polar function called
# 8:288 minutes, 28 secondswhich says take a column and give it a name. Right? And so we can say alalias app rate and that says this column which
# 8:358 minutes, 35 secondsis applied divided by grade 12 um call it app rate. Right? That's the name of that column. And then when we say
# 8:428 minutes, 42 secondscolumns into the named column then it adds it in with that name. This is new from last time, but Dan, just a different way of doing things. You'll
# 8:498 minutes, 49 secondssee people do it both ways. If you interact with a large language model, it might generate code one of both ways. Both totally legitimate.
# 8:588 minutes, 58 secondsUh, and then last but not least, we saw the ability to filter, right? How do we filter? Well, we say filter. And what do
# 9:069 minutes, 6 secondswe give it? We give it a condition, right? where we construct essentially an expression that has what we want as true
# 9:149 minutes, 14 secondsor false. Right? So we say take the application rate column right which is an entire column full of one application rate for every school. Say less than or
# 9:239 minutes, 23 secondsequal to one. So for each school is that schools appate less than or equal to one. So that'll be like true false false true true true false true false true
# 9:319 minutes, 31 secondsfalse and so on. And then the filter will say keep all the rows where that condition is true.
# 9:409 minutes, 40 secondsSo that's the polar code. And then the SQL code here is also uh listed as well.
# 9:459 minutes, 45 secondsAnd I'm not going to go over that because you hopefully have seen that before in a previous class. You can check out the head post for review and I talked a little bit about it last time.
# 9:529 minutes, 52 secondsOkay. Any questions on the code that we've learned so far?
# 10:0710 minutes, 7 secondsSo again, I want you to notice that we have spent way less time in the last couple classes on the code than on a the
# 10:1310 minutes, 13 secondsEnglish descriptions, but b what we can do with the English descriptions, how we think about data, learning to ask those questions. Those are the most important
# 10:2210 minutes, 22 secondsskills for a data scientist to have. If you go to a data science interview and you say like, "Oh, I'm really good at writing code." somebody's going to be like, okay, like that's not necessarily
# 10:3010 minutes, 30 secondsthat useful. You know, we have um people who can write code with a large language model and we have these other people who can think about the data. They're the ones who are going to get hired. So, you
# 10:3810 minutes, 38 secondswant to be one of those people. Make sure you understand how to think about the data, ask questions, and that's a skill you develop with practice. How do
# 10:4610 minutes, 46 secondsyou get the practice? Come to class, talk with the person next to you, kind of like push, pull, and push yourself outside your comfort zone to be able to ask those questions.
# 10:5610 minutes, 56 secondsOkay, we spent a little bit of time on histograms right at the very end. We kind of rushed to this so I'll cover it again. We said, you know, again, quick
# 11:0411 minutes, 4 secondsrecap from data 8, right? Histogram is a way of representing the distribution of data. Uh we use area to represent how
# 11:1111 minutes, 11 secondsmuch uh data lives in each of these bins, right? So the area of a bin represents the uh
# 11:2011 minutes, 20 secondsamount of data that lives there. So the the y-axis is this weird density thing.
# 11:2411 minutes, 24 secondsIt's kind of weird if you think about it in the abstract, but then realize that the area is most important. Density is just like the x divided by the area
# 11:3211 minutes, 32 secondsdivided by the x. So we said a distribution with one peak is called unimodal, right? This distribution over
# 11:3911 minutes, 39 secondshere has one single peak and it has remember we said a right skew meaning a tail that goes off to the right.
# 11:5011 minutes, 50 secondsThis distribution has more than one peak. So if it's two peaks we say it's biodal right so this distribution has uh
# 11:5711 minutes, 57 secondsa peak sitting over here and a peak sitting over here right so there are two peaks in this distribution
# 12:0712 minutes, 7 secondsnow I say there are two but you know maybe you make the argument that there's actually three or maybe even four does
# 12:1412 minutes, 14 secondsthis one matter these are not like hard and fast terms these are kind of like subjective judgments
# 12:2212 minutes, 22 secondsSo if we have more than two peaks, we say something is multimodal. Again, these are not like hard and fast terms.
# 12:2812 minutes, 28 secondsThey're usually uh subjective based on, you know, is this is this peak important or not?
# 12:3512 minutes, 35 secondsSo it's unimodal, that's biodal, maybe it's multimodal.
# 12:4012 minutes, 40 secondsSo what I want to start with today is answering the question of why, right? So again, whenever you're looking at a data
# 12:4712 minutes, 47 secondsset and you see a visualization, you want to push yourself to think why. Why is what is happening happening? And how am I going to communicate and explain
# 12:5612 minutes, 56 secondsthat to whoever cares about the data? So I want you to start by answering the question and turn to the person next to you. Why is there variation in application rates across schools? Right?
# 13:0713 minutes, 7 secondsWhy why do why do different schools have different application rates? All right, take a minute. If you don't know the person next to you, introduce yourself.
# 13:1413 minutes, 14 secondsAgain, this is where you're going to get the practice. This is not something that you just like can go to the street and get. This is what you're going to need to do in an interview. Take the time
# 13:2113 minutes, 21 secondsnow. Practice uh answering, asking why, challenging each other.
# 17:3517 minutes, 35 secondsAll right, so let's come back. Uh, can someone share what you came up with for why? And again, hopefully you had a
# 17:4317 minutes, 43 secondschance to come up with more than one reason because there obviously are more.
# 17:4617 minutes, 46 secondsThere are many reasons. Can someone share one of the reasons that you came up with in your discussion? Someone from over here. Yes, back.
# 18:1618 minutes, 16 secondsYeah, right. People from some schools might be have resources to be better prepared and more likely to think, well, yeah, I can get into Berkeley, whereas
# 18:2418 minutes, 24 secondssomeone from a a less resourced school might not think that they uh can get in, so they might not apply, right? So, access to resources, super important.
# 18:3318 minutes, 33 secondsUm, another another possibility Yes.
# 19:0019 minutesYes. Exactly right. Interest. Right.
# 19:0119 minutes, 1 secondSome students might be more interested in UC's. Other students might be more interested in uh applying to transfer schools, applying to trade schools,
# 19:1019 minutes, 10 secondsright? Maybe a high school has a really good vocational program that prepares people to go into a trade school, become an electrician, make more than we might make as a data scientist. Uh but there's
# 19:1919 minutes, 19 secondslots of reasons around interest. Um any others? Yes.
# 19:2619 minutes, 26 secondsYeah. Some people not might not even apply to college, right? There may be people who just choose not to apply to college, right? All totally possible.
# 19:3619 minutes, 36 secondsOkay, so let's hide these little controls. So another reason that uh we might think of oops, there's a slide.
# 19:4419 minutes, 44 secondsWe'll skip the slide out. It's fine. Um so the decision to apply is complex, right? These are just a handful of reasons that you all came up with and I'm sure that you know many other folks
# 19:5219 minutes, 52 secondswho I didn't get to call on came up with even more, right? Things like money, uh academic resources, right? Going to UC's
# 19:5919 minutes, 59 secondsis relatively expensive compared to maybe it's cheaper than a private school, but it's more expensive than going to a community college or maybe to
# 20:0720 minutes, 7 secondsa CSU depending. Um, there's also individual priorities, family priorities. Some people might choose to
# 20:1520 minutes, 15 secondsgo to school closer to home or farther from home, right? So, distance from the school to to Berkeley might be important. And again, remember, we're
# 20:2320 minutes, 23 secondsjust focusing on UC Berkeley 2025, right? people who got in in 2025. We're not looking at all UC's even though we
# 20:3120 minutes, 31 secondscould have that data. We narrowed down and limited our analysis to just Berkeley 2025.
# 20:3720 minutes, 37 secondsSo, there's a lot of different ideas. Do we have access to all of this? Well, do we have access to data on what every
# 20:4520 minutes, 45 secondssingle student is like interested in career-wise?
# 20:4920 minutes, 49 secondsMaybe not, right? Because that involves like going out and interviewing people.
# 20:5320 minutes, 53 secondsBut maybe that data isn't available. But there is a lot of data that we do have access to, right? Specifically, again, I
# 21:0121 minutes, 1 secondwant to encourage do not just like give up and say, "Oh, we don't have the data.
# 21:0521 minutes, 5 secondsI can't do it. It's too hard." Always think, "Can I get the data?" Right? Can I go look find some public data set? Uh, and if not, can I go talk to somebody
# 21:1321 minutes, 13 secondswho has the data, build a collaboration with them, get access to the data, and maybe help them in the process uh as well.
# 21:2221 minutes, 22 secondsSo, California Department of Education, again, as I mentioned, you know, I flashed this up last time, has a lot of data. And in particular, if we click
# 21:3021 minutes, 30 secondsthrough to the this thing of downloadable data files, there's a whole bunch of data they have on schools, right? They have things like
# 21:3821 minutes, 38 secondsabsenteeism. Oops, not want to cross that out.
# 21:4421 minutes, 44 secondsRight? They have absenteeism, accountability, um, and they have things that we care about, things like annual enrollment, right? They have assessment test scores, uh, all this other stuff.
# 21:5521 minutes, 55 secondsSo, we talked about financial resources.
# 21:5821 minutes, 58 secondsOne common way that people use to kind of measure as a proxy for financial resources is access to free and reduced
# 22:0522 minutes, 5 secondsprice lunch. Right? So many schools uh many states offer free lunch uh or reduced price lunch to people who uh
# 22:1322 minutes, 13 secondscome from families with lower socioeconomic background, families who don't have as much money. Um there's also, you know, public school, public
# 22:2122 minutes, 21 secondsdistrict. So if we look at the enrollment, right, we can uh get information there. That's where we ended up getting the number of 12th graders in each school. There's free reduced price.
# 22:3222 minutes, 32 secondsNo, why didn't it work? All right. Well, if we click through to this, it'll tell us information about the uh free and reduced price meal program, right? And
# 22:4022 minutes, 40 secondsthis is a typical proxy. Not everyone who could get access to this gets access. Why not? Well, because you have
# 22:4922 minutes, 49 secondsto apply, right? You have to know how to apply. You have to spend the time and energy applying. So many programs are like this where there are people who
# 22:5622 minutes, 56 secondscould benefit from it who don't. So often the the data on the percent of people who get free and reduced price lunch might be an undercount of the
# 23:0423 minutes, 4 secondsactual number of people who uh have less financial resources.
# 23:1023 minutes, 10 secondsOkay. We can also get information about every school's latitude and longitude and then use like a little Pythagorean theorem to calculate the the distance to
# 23:2023 minutes, 20 secondsuh to cal. So by doing that we then add in these extra columns, right? So last time we joined in these total number
# 23:2923 minutes, 29 secondsenrolled in grade 12 columns. Today we're going to now add in three more columns is charter percent free reduced
# 23:3723 minutes, 37 secondsand distance to UCB in months. And we did all this for you behind the scenes, right? The the join of doing this. We'll
# 23:4523 minutes, 45 secondstalk more about joins next week, but we did the join. Uh like I mentioned last time, there are some issues with the join which you'll explore. This join
# 23:5323 minutes, 53 secondsgets even trickier. Why is this join trickier? because well we have names of schools right anytime we have names of
# 24:0024 minutesschools in one data set the names might be listed slightly differently right we think about like AB Miller high school
# 24:0724 minutes, 7 secondsmaybe the A and AB is fully spelled out right maybe it's like Alfred Barnes Miller or something like that and so we have to match AB Miller with Alfred
# 24:1624 minutes, 16 secondsBarnes Miller how do we know this is called a fuzzy match it's a tricky problem um it's the kind of thing that maybe you want to like look up how people have done it before use a large
# 24:2524 minutes, 25 secondslanguage model to suggest ideas, but think carefully about what it's doing to make sure that it doesn't guide you down the wrong path. Right? Um my
# 24:3224 minutes, 32 secondsco-instructor from the spring for this class, Josh Gman, who uh actually built this data set, um one of the things that
# 24:3924 minutes, 39 secondshe found when talking with a large language model is that the first few things it suggested for how to match the schools did not make sense. And so he had to like iterate and refine and
# 24:4824 minutes, 48 secondsrepeat the prompting and process and think critically in order to get them to join and come out nice.
# 24:5524 minutes, 55 secondsOkay, so now I want to ask a question, right? So this is we can think about the distances and make a box plot, right? We talked all about box plots last time,
# 25:0425 minutes, 4 secondsright? We have the the box, the line with the median. We have the edges of the box which tell us Oops, I don't need emojis.
# 25:1425 minutes, 14 secondsWe have the edges of the box, right, which tell us the third quartile and first quartile. And then we have these
# 25:2125 minutes, 21 secondswhiskers which go out to the outlier uh thresholds and we have outliers of the dots. No outliers here.
# 25:2925 minutes, 29 secondsSo if we have this box plot right we can think about this is okay this is the the distribution but what is the histogram going to look
# 25:3825 minutes, 38 secondslike? No the slid doesn't have the picture. Okay. Um, we'll try to keep the slido open, but if this is what the histogram looks like, take a minute,
# 25:4725 minutes, 47 secondsturn to the person next to you, and discuss what does the histogram look like? If this is the box,
# 27:2527 minutes, 25 secondsAll right. So, I want all of you like use your hands just kind of like show me what the the shape you think uh things
# 27:3227 minutes, 32 secondsare going to look like. So, what do you what do you think? Just kind of like going like is it like this? Is it
# 27:4127 minutes, 41 secondsAll right. I'm seeing a lot of like kind of like this, right? We have this thing in the center. So maybe there's like a
# 27:4827 minutes, 48 secondspeak there. The like right whisker is a little longer than left whisker. So maybe there's some right skew, right? Um I'm seeing skewed right, skewed left.
# 27:5827 minutes, 58 secondsLots of possible answers. But how many people expected it to look like this?
# 28:0428 minutes, 4 secondsNot not counting people who looked ahead in the slides. A few people, right? How many people did not expect it to look like this? Yeah, if I had just looked at
# 28:1228 minutes, 12 secondsthe box plot, I would raise my hand for I would not have expected this either.
# 28:1628 minutes, 16 secondsNow, thinking about the data though, does this uh histogram make sense?
# 28:2428 minutes, 24 secondsRight? Are there reasons why we would see such a strong pattern?
# 28:2928 minutes, 29 secondsWell, yes, there are. We'll talk about those in a sec. But here, I want to impress upon you a big takeaway. A histogram shows more information than a
# 28:3828 minutes, 38 secondsbox plot, right? Does that mean box plots are useless and you should always use histograms? Absolutely not. Right?
# 28:4428 minutes, 44 secondsSometimes the extra information in a histogram creates more cognitive load on whoever you're showing it to. So, it's better to use the box plot. But if
# 28:5128 minutes, 51 secondsthere's something hidden in the histogram, then you being deceptive if you try to use a box plot to show that information, right? So box plots great
# 29:0029 minutesas long as you know whoever interpreting the box plot is going to like make the right conclusions. But if you have something like this, you're better off
# 29:0729 minutes, 7 secondsshowing the histogram, right? We can go even further in that direction by adding more bins to the histogram. Right? The more bins we have, the more the
# 29:1629 minutes, 16 secondshistogram, you know, the finer detailed it gets in Seabor that corresponds to specifying the number of bins here.
# 29:2629 minutes, 26 secondsSo there's and you know people have thought about like what's the optimal number of bins? Seabour does a good job of trying to like calculate it for you.
# 29:3329 minutes, 33 secondsUm are more bins always better?
# 29:3629 minutes, 36 secondsNo. Right. You can imagine like going to a ton of bins and then each point is just like an individual little spike.
# 29:4329 minutes, 43 secondsRight? So I would actually argue that the version on the right is just as good, maybe better than the one on the left. Sure, the one on the left gives a
# 29:5129 minutes, 51 secondslittle more information, but I can get the pattern from the one on the right.
# 29:5629 minutes, 56 secondsWhich one you actually want to use depends on what you're trying to communicate, right? If the person you're trying to communicate to is going to care about things like this little dip
# 30:0430 minutes, 4 secondsin between here or uh you know this these little like jagged pattern here, then maybe you should use the one with
# 30:1330 minutes, 13 secondsmore bins. But most of the time something like this is going to be easier for the person to kind of like quickly understand what's going on and
# 30:2030 minutes, 20 secondswork with. Okay. So why are there three peaks, right? Why is this a trrimodal distribution with one peak over here,
# 30:2930 minutes, 29 secondsone peak here, and one peak here? And just to make your lives easier as you answer the question, I have a map up here with California with the population
# 30:3830 minutes, 38 secondsdensity, right? So brighter red means, you know, more people live there. And I've overlaid a little thing of cow there. All right, take a minute, turn to
# 30:4630 minutes, 46 secondsthe person next to you, and answer the question, why are there three peaks? And we're going to go kind of quick on this one.
# 31:3831 minutes, 38 secondsAll right. So, uh, why are there three peaks? Someone want to tell me what the first peak means? The one furthest to
# 31:4531 minutes, 45 secondsthe left. Any ideas for like what the that first, uh, first peak corresponds to the one furthest all the way on the
# 31:5331 minutes, 53 secondsleft? Yes, the Bay Area. Right. Again, distance used to be in miles. They have three peaks because there are three
# 32:0032 minutesmajor population centers in California, right? There's the Bay Area, there's another one in LA, and then there's
# 32:0732 minutes, 7 secondsanother kind of slightly smaller but still big population center in San Diego. There's also a big center near Sacramento. Um, and there's a little
# 32:1432 minutes, 14 secondsbit, you know, decent population in the Central Valley. So, we can read all of what I just said off of this histogram, right? Because we can see that, well,
# 32:2332 minutes, 23 secondsthis is the Bay Area. This is basically the central valley and probably also Sacramento.
# 32:3432 minutes, 34 secondsAnd this bigger peak over here corresponds to LA.
# 32:3932 minutes, 39 secondsAnd then this smaller peak corresponds to San Diego.
# 32:4432 minutes, 44 secondsNotice that in between LA and San Diego, things don't go down to zero, right?
# 32:4832 minutes, 48 secondsLike this data over here, right? The bins are a lot higher. There's more density, more people, more high schools than there are over here. Why?
# 32:5932 minutes, 59 secondsWhat's between LA and San Diego?
# 33:0333 minutes, 3 secondsOrange County, right? Orange County, Irvine. Uh there's a whole And you can even see that on the map, right? Like it doesn't uh go to white. It goes it stays
# 33:1033 minutes, 10 secondsa slightly lighter shade of red, meaning that there's still population density there.
# 33:1633 minutes, 16 secondsSo, this is all important stuff to be able to like read off a histogram, right? like I read the histogram and I think what is the context? Why are the
# 33:2333 minutes, 23 secondspatterns I'm seeing happening? And the next step which we're going to spend more time when we talk about visualization is how do you communicate that to somebody who might not know as
# 33:3133 minutes, 31 secondsmuch about the data. Right? Part of the reason we're working with this data set is because all of you are experts on high schools on applying to college on
# 33:4033 minutes, 40 secondsadmissions and most of you uh you know the ones who are from California are probably also experts on you know California where schools are and so on.
# 33:4933 minutes, 49 secondsBut in many data problems you work with many data sets you will not necessarily be the domain expert right and you will not be explaining things to people who
# 33:5633 minutes, 56 secondsare domain experts. So you want to like think about how do you communicate this kind of stuff out to other people.
# 34:0434 minutes, 4 secondsUh so if we want to find out this information from the data one thing we can ask is for the counts of different cities right and how do we do this?
# 34:1734 minutes, 17 secondsWell, we take our city and what we want to do is for each city we want to count the number of rows, right? Count the
# 34:2434 minutes, 24 secondsnumber of schools, right? And how do we do that? Well, in our data, we count the number of rows for each city. So, this
# 34:3134 minutes, 31 secondskind of operation for each something, do or calculate something is super common and you're going to see it all
# 34:3834 minutes, 38 secondsthe time. If you have time at the end of class today, we're going to like start getting into grouping, which is how we we do this. And if not, it'll be the topic for the majority of next week.
# 34:4634 minutes, 46 secondsWell, either way it'll be a majority next week.
# 34:4934 minutes, 49 secondsSo in polars we can do something called value counts. We can take a column right which we extract a column using brackets
# 34:5634 minutes, 56 secondsand then we say dot value counts that gives us essentially we take you know every possible value count how many times it happens and then if we just get
# 35:0535 minutes, 5 secondsthat then we just you know like get all the the the cities count to how many schools but if we sort them in descending order then we get something
# 35:1435 minutes, 14 secondslike this right where the most city with the most schools is at the top and so on all the way down to the bottom right and this is just the the top And so we can
# 35:2335 minutes, 23 secondssee already that we have LA and San Diego, right? Which are like this blob over here, right? We
# 35:3335 minutes, 33 secondshave the Bay Area, right? San Jose, Oakland.
# 35:3835 minutes, 38 secondsSome people will complain if I include Sacramento in the Bay Area because it's not technically but you know if we include it we can say that all of these
# 35:4635 minutes, 46 secondscorrespond to what's going on over here right and Stockton again not quite the Bay Area but closeish
# 35:5535 minutes, 55 secondsand then last but not least we have the central valley right Fresno Bakersfield over here which corresponds to what's
# 36:0436 minutes, 4 secondsgoing on here right so we can think Right? Not just we can connect the visualization to what we know about the state of California to
# 36:1236 minutes, 12 secondsour summary of the data. All of these things are connected and we have to make the mental connections. Right? No amount of like prompting or or things like that
# 36:2236 minutes, 22 secondswill get you the insight and intuition that you can bring by knowing something about the problem.
# 36:2936 minutes, 29 secondsOkay. So, uh you know why is there variation? We talked about this uh in
# 36:3636 minutes, 36 secondsterms of distance. So for the next few minutes I want to talk about how application rates relate or correlate with free and reduced lunch percentage.
# 36:4636 minutes, 46 secondsRight? So for every school remember I brought in I used the join to bring in data on the percentage of students receiving free or reduced price lunch which are we're going to call FRL.
# 36:5836 minutes, 58 secondsAnd we're going to use correlation because now we're not just looking at one variable at a time. Right? For one variable at a time, histograms are
# 37:0737 minutes, 7 secondsgreat. Uh box plots are great. But when we want to look at multiple variables at a time, what kind of visualization do we want to use?
# 37:1837 minutes, 18 secondsWe can't use the histogram, right?
# 37:1937 minutes, 19 secondsBecause histogram shows us the distribution of one. Yes.
# 37:2237 minutes, 22 secondsYeah. A scatter plot, right? Not the only answer, but it's the answer we're going to uh use for now. We'll talk more about more uh types. Remember this is
# 37:3037 minutes, 30 secondswhat our data set looks like, right? We have for every school applied a metend number of enrolled in people in grade 12. We have the application rate column that is not shown in this version.
# 37:4037 minutes, 40 secondsRight? We divided applied by grade 12.
# 37:4437 minutes, 44 secondsAnd then we have these two new columns free and reduced and distance to Berkeley.
# 37:5037 minutes, 50 secondsSo oops this is not the version I wanted.
# 37:5637 minutes, 56 secondsAll right. While where is the version without the Okay, that's fine. Um,
# 38:0638 minutes, 6 secondsall right. So, this is what the scatter plot looks like, right? So, I have a scatter plot here of the uh on the
# 38:1438 minutes, 14 secondsx-axis, right? This is a percent free reduced people getting percentage of people getting free reduced lunch. On the y- axis is the application rate. And
# 38:2238 minutes, 22 secondshow do I do this? Well, I can use sns.catterplot. scatter plot or in this case since I'm adding a line on top of it I use snssreg
# 38:3138 minutes, 31 secondsplot for regression right so in day eight you saw regression using a line but is a line a good fit for this
# 38:3838 minutes, 38 secondspattern that's happening here well probably not right it's kind of like if I look at the pattern right I
# 38:4538 minutes, 45 secondssee a whole bunch of schools that have relatively low application rates
# 38:5238 minutes, 52 secondsacross a wide range of free reduced lunch percent and then over here with schools that have less I see a
# 39:0239 minutes, 2 secondswhole bunch of them with a lot of people applying right so there's kind of two distinct patterns and so maybe something other
# 39:0839 minutes, 8 secondsthan a line is useful as a way of talking about this so again when you go to visualize something don't just you
# 39:1739 minutes, 17 secondsknow run in uh you know type into a prompt model hey how do I uh do this you want to think what is the right way to
# 39:2639 minutes, 26 secondsanalyze and think about this data. What kind of line should I use?
# 39:3139 minutes, 31 secondsUm there's a there have been a whole bunch of studies in the last like year, year and a half about pe how people who depend on large language models tend to
# 39:4039 minutes, 40 secondshave deterioration in their cognitive skills. Right? This has been shown there's this um study from the MIT Media Lab um where you know they had people
# 39:4939 minutes, 49 secondswrite essays. There are studies of people online doing like math tasks.
# 39:5339 minutes, 53 secondswhole bunch of different uh ways that people do this that all generally have the same conclusion. If you uh use this,
# 40:0040 minutesyou know, if you use LLMs to rely on them too much, then you think you know more than you do. And people who rely on them too much tend to do worse when
# 40:0840 minutes, 8 secondstested on the knowledge that they think they learn. Okay, so we're going to use something called Lois to help us with
# 40:1640 minutes, 16 secondsthis. And this Lois is the way that we're constructing this little curved line. Uh if you remember from data eight
# 40:2440 minutes, 24 secondsright when you had that thing of heights you thought we thought about like well we can kind of make a line for every point we just like look at all the
# 40:3140 minutes, 31 secondspoints nearby right and use that as our guess of the y right we look at all the points that are near an x use their average and use that as our guess for
# 40:3940 minutes, 39 secondsthe y kind of how low works so if we take people who are in this range and look at their uh this range of free
# 40:4740 minutes, 47 secondsreduced price lunch look at their average application rate it's here and do the same for here and for here and for here right so we average all the
# 40:5540 minutes, 55 secondspoints nearby now it's an oversimplification it's slightly more sophisticated than this but a
# 41:0441 minutes, 4 secondsquestion I want to ask you is should every point have an equal influence on that line in other words are some points
# 41:1341 minutes, 13 secondsin this visualization more important than others should we have more weight assigned to some of these points what
# 41:2141 minutes, 21 secondsmight be a reason that matters.
# 41:3341 minutes, 33 secondsYes.
# 41:3941 minutes, 39 secondsYeah. If the bin has more points, right, we should have given it more weight. But then within each of the individual points themselves, right, in the bin,
# 41:4641 minutes, 46 secondslike is there a reason that this point might be more or less important than this point?
# 41:5141 minutes, 51 secondsRight? Or like even these two points that are right next to each other, right? Is there a reason that one might be more important than another? Right?
# 41:5941 minutes, 59 secondsWell, again, we have to think each of these points corresponds to a school, right? What information about schools might make one school more or less relevant in our analysis? Yes.
# 42:1042 minutes, 10 secondsYeah. The number of students, right?
# 42:1242 minutes, 12 secondsMaybe we should say, well, schools who have more students, we should think about them as having more weight than others.
# 42:2142 minutes, 21 secondsSo in other words, we probably want to give more weight to bigger schools than to smaller schools.
# 42:3042 minutes, 30 secondsUm we'll skip this slide though and go to this one.
# 42:3542 minutes, 35 secondsSo here I have the original scatter plot right up on the top left right where on the x axis you have number of students with free reduced price percent students
# 42:4242 minutes, 42 secondsfree reduced price lunch y axis is application rate and then I have three versions where I've sized the points
# 42:4942 minutes, 49 secondsdifferently based on something related to number of students for B I've used grade 12 number of 12th graders as the
# 42:5742 minutes, 57 secondssize for C I've used total enrollment as the size and for D I've used the number of students who applied as the size.
# 43:0843 minutes, 8 secondsSo what does each one of these four plots communicate? Well, I would argue that plot A is a little misleading,
# 43:1543 minutes, 15 secondsright? If we think about these uh schools over here, right? Like this school over here is like getting a
# 43:2243 minutes, 22 secondsthere's a lot of students who have uh free reduced price lunch but a relatively high application rate, right?
# 43:2843 minutes, 28 secondsMaybe there's something interesting going on with this school. But when I look at this in the version here, I can see that gosh, that school is really
# 43:3643 minutes, 36 secondssmall, right? So maybe it's it's unique, maybe it's special, maybe it's a charter school, maybe there's something going on there, right? So point graph A is
# 43:4443 minutes, 44 secondsmisleading because it emphasizes a lot of these points, right? These schools that are uh outliers over here, well,
# 43:5343 minutes, 53 secondsthey're they show up as actually being quite small schools, right? So we have these schools that are
# 44:0044 minutesquite small and so this visualization of in B kind of helps us see that right helps us see that hey some of these
# 44:0744 minutes, 7 secondsschools are bigger than others. C does basically the same thing except instead of uh number of 12th graders it's total
# 44:1444 minutes, 14 secondsenrolled. Right? So B and if we look at B and C kind of qualitatively and squint, we can see that they look pretty similar, right? They're kind of
# 44:2244 minutes, 22 secondsconveying the same information. Um and we saw that there's a strong correlation between number of 12th graders and total
# 44:3044 minutes, 30 secondsnumber of people enrolled. And so yeah, sure there's, you know, people drop out as they go from year to year. Um, some schools offer more or fewer grades, but by and large B and C are very similar.
# 44:4144 minutes, 41 secondsSo, we're going to like mostly focus on comparing B. What about D? What if we put the number of people who applied as
# 44:5244 minutes, 52 secondsthe size? Well, here then we get a pattern that we should think about and expect, right? where the points near the
# 45:0045 minutestop of the graph end up being bigger than the ones near the bottom, which kind of makes sense, right? Because there's a redundancy here, right?
# 45:0845 minutes, 8 secondsBecause points higher up have a higher application rate, which means they have a higher percent of students applying.
# 45:1545 minutes, 15 secondsSo, it kind of makes sense that if they have a higher percentage of students applying, they should also have more students applying. Not universally, right? We get some difference, right?
# 45:2445 minutes, 24 secondsLike we can see this school over here, right? Which is the same as this one, right? and this school over here which
# 45:3045 minutes, 30 secondsis the same as this one are pretty small but there's some amount of redundancy right there's a redundancy between the
# 45:3845 minutes, 38 secondssize and the y-axis is that redundancy necessarily bad no if I want to emphasize that right if I want to like
# 45:4645 minutes, 46 secondsreally lean into that then maybe that's useful but there is some redundancy there okay so I want you to compare
# 45:5445 minutes, 54 secondsspecifically B and D right the version where we have the size is the number of 12th graders and the size is the number who applied. And I want you to answer
# 46:0346 minutes, 3 secondsthe question, which one of these two is better?
# 46:0646 minutes, 6 secondsAgain, I'm being kind of vague here with better, right? So, you might have to start by answering what does better mean before you can answer which one is
# 46:1446 minutes, 14 secondsbetter. All right, take a minute, turn to the person next to you, and discuss and then vote.
# 47:2147 minutes, 21 secondsAll right. So, let's see how people voted. So, we have more people saying B than D.
# 47:2747 minutes, 27 secondsInteresting. Um, so a lot of times when I show start by showing this, I start to see more people vote for the thing that happens to have more answers. Um, I do
# 47:3547 minutes, 35 secondslike to put questions up that are like a little tricky where the more intuitive answer is not necessarily the right one.
# 47:4047 minutes, 40 secondsSo if you see you're voting for the less common answer, don't immediately think that you're wrong. Try to like think about why you voted for the answer you
# 47:4747 minutes, 47 secondsvoted for. Okay, that being said, I don't think there is a right answer here, right? I think that there are good reasons why someone might want to choose
# 47:5647 minutes, 56 secondsB and there are good reasons why someone might want to choose D. Right? For most cases, I would probably go with B most
# 48:0448 minutes, 4 secondsof the time, more often, right? So maybe B is like kind of sort of better. But again, in order to answer that, we have to think about what does better mean,
# 48:1348 minutes, 13 secondsright? B kind of clearly communicates where size corresponds to number of students. It's kind of intuitive. It's
# 48:2048 minutes, 20 secondsclear what's going on. When someone sees a bigger point, it means a bigger school. Smaller point means smaller school. Kind of matches up with our natural intuition.
# 48:3048 minutes, 30 secondsWhereas D, the size is doing something a little funky, right? where the size is the number of people who applied and
# 48:3748 minutes, 37 secondsagain I said that's redundant with the y-axis which is the application rate that being said it is interesting right
# 48:4548 minutes, 45 secondsbecause if we're using B then we're kind of communicating about potential applicants right the size is telling us
# 48:5248 minutes, 52 secondshow big is the school how big is how many 12th graders are there what is the number of potential students who could apply whereas with D the size is telling
# 49:0249 minutes, 2 secondsus what are the number of actual applicants the size is telling me how many right emphasizing hey in these
# 49:0849 minutes, 8 secondsschools a lot of people applied and uh you know I'm have an easier time picking out the pattern of hey I had a lot of
# 49:1749 minutes, 17 secondspeople who applied in these schools right where they had relatively low percent of free reduced price lunch
# 49:2649 minutes, 26 secondswhereas these schools right with high also high application rates had a lot fewer people applying
# 49:3449 minutes, 34 secondsRight? So there's kind of like easy to read off facts like that. So one isn't necessarily better than the other. It depends on what you're trying to
# 49:4249 minutes, 42 secondscommunicate. So anytime you're deciding between a visual different ways of visualizing, which you often will be, think about what you're trying to
# 49:4949 minutes, 49 secondscommunicate, who you're communicating it to, and what you want them to get out of it. So how do we go about doing the sizing?
# 49:5749 minutes, 57 secondsRight? This is the kind of thing where looking it up or using a large language model is a great way to do it. I personally can rarely remember all the
# 50:0550 minutes, 5 secondsdetails of how to specify this right with Seabor it's important to know that you know you pass in your data frame and then you can give it like the X the Y
# 50:1350 minutes, 13 secondsthe size um we can also resize the points by number of potential applicants um but again there is no one
# 50:2250 minutes, 22 secondsright answer sometimes it can be helpful to like vary the sizes right to not have the sizes be um oh like you know I want
# 50:3150 minutes, 31 secondsuh like if we compare these two right both of these are sized by number of 12th graders but notice that the second
# 50:3950 minutes, 39 secondsone this one it's kind of like emphasizing the point more right here the points all look kind of similar even
# 50:4650 minutes, 46 secondsthough there's variation but here if I say the sizes are kind of like between one and 100 then that modifies the range
# 50:5550 minutes, 55 secondsof the sizes this is a great thing to use a large language model or to look up in the documentation right I've been using Seabor for like more than 10
# 51:0351 minutes, 3 secondsyears. I would not know how to do this off the top of my head if you asked me. I would have to go look it up.
# 51:0951 minutes, 9 secondsUm talked about this.
# 51:1351 minutes, 13 secondsUm okay. So let's do some practice writing code. Right? A lot of the practice we've done has been on uh
# 51:2251 minutes, 22 secondsthinking about data. But you know we are going to expect you to know how to write some basic code in this class. So let's get some practice. So I want you to
# 51:2951 minutes, 29 secondswrite Polers code that adds a new column to this data frame with the number of nth of 12th graders who get free reduced
# 51:3851 minutes, 38 secondsprice lunch. Um and then after you do that think about is it possible that the calculation you made might be wrong. If
# 51:4451 minutes, 44 secondsso power why but just because it might be wrong doesn't mean don't do it means do it and be honest about how it might be off. All right feel free to discuss.
# 51:5451 minutes, 54 secondsIf you want to like think by yourself for a moment before you discuss, totally cool, too.
# 52:3652 minutes, 36 secondsAll
# 52:5252 minutes, 52 secondsright. If you haven't already, turn to the person next to you and discuss what you have.
# 54:1454 minutes, 14 secondsAll right. And quick reminder on slido, right? How are these slidos work? The way it works is you scan the QR code and
# 54:2154 minutes, 21 secondsthen log in and enter your thing. Um, if you are here in lecture, if you complete the slidos, we will mark your attendance. If you're watching this
# 54:2954 minutes, 29 secondsafter the fact on the recording, then you'll need to for the ones where there's a correct answer, you'll need to get the correct answer uh in order to
# 54:3754 minutes, 37 secondsget full credit. Okay. So, how would we go about adding this column to our data
# 54:4454 minutes, 44 secondsset? Well, okay. And I know that sometimes when I move on to the slide, it closes the
# 54:5254 minutes, 52 secondsslido. This is an issue. Normally that does not happen. There's an issue with Slido. We're trying to resolve it. Um, if that happens to you, don't worry too
# 54:5954 minutes, 59 secondsmuch about it. Uh, we'll we'll figure it out. Okay. So, uh, how do we add the number of 12th graders as a new column?
# 55:0855 minutes, 8 secondsWell, in order to add a new column, we need to use the width columns uh
# 55:1655 minutes, 16 secondsmethod, right? So, we say df and we're calling it df new. If you didn't remember that, totally fine. It's not the point of this question, right?
# 55:2655 minutes, 26 secondsBut we add a column by using the width columns method.
# 55:3355 minutes, 33 secondsAnd what is the new column we're adding?
# 55:3555 minutes, 35 secondsWell, it's the number of 12th graders who receive free reduced price free or reduced price lunch. How do we calculate
# 55:4355 minutes, 43 secondsthe number? So, someone wanted in English describe to me what we need to do in order to calculate the number of 12th graders from the data that we have.
# 55:5355 minutes, 53 secondsYes. Yeah. Uh in the cap basil cap. Yes.
# 56:0556 minutes, 5 secondsYeah. Right. We can take the free reduced price lunch percentage multiply it by the number of 12th graders. Right.
# 56:1256 minutes, 12 secondsSo we need to take the number the percent of free reduced price lunch which we get using pl.all
# 56:2156 minutes, 21 secondsof um I forget exactly what the column is called. We're going to say something like percent FRL
# 56:3056 minutes, 30 secondsand then multiply that by the number of 12th graders,
# 56:4256 minutes, 42 secondsright? And again, I'm being fast and loose about what the names of the columns are just because I forgot to put that on the slide. Um, but that's something where you always want to look
# 56:5056 minutes, 50 secondsit up. Okay? And then now I have the column, but I need to give it a name to
# 56:5656 minutes, 56 secondsname it the number of 12th graders. So the easiest way, well, there's two perfectly easy ways to do it. One is to
# 57:0457 minutes, 4 secondsput the name in front as a named argument. The other is to alias. Either way, totally fine.
# 57:1357 minutes, 13 secondsNum 12th graders with free or reduced price lunch.
# 57:2257 minutes, 22 secondsRight. So, this would be a perfectly valid answer. Well, it would be if I got gotten the column names right. Right.
# 57:2957 minutes, 29 secondsAnd if you don't like my handwriting, which totally fair. Um, here's a version that has it. Notice in this version I uh
# 57:3657 minutes, 36 secondsin the slide I added an extra step, right? I added this step called cast
# 57:4257 minutes, 42 secondsint. What is what is that about? Well, if I think about the if I want a estimate for the number of 12th graders
# 57:4957 minutes, 49 secondsand I take a percentage and multiply by something then I might get a fractional number of uh student right which maybe I
# 57:5957 minutes, 59 secondsdon't want and so I might want to round so I can say passive of int say round
# 58:0558 minutes, 5 secondsand then I say alias okay questions on the code
# 58:1758 minutes, 17 secondsGreat point, right? Question was, wouldn't the percentage of the uh free and reduced lunch be for the entire school, not just the number of 12th
# 58:2558 minutes, 25 secondsgraders? Right? So, this gets to the second part of the question, uh, which is good. But before we get there, I want to answer any questions people might
# 58:3358 minutes, 33 secondshave about the code specifically. Um, and then we'll get into that.
# 58:3858 minutes, 38 secondsAny questions about how we wrote the code? Right, remember we pulled out the columns using plall,
# 58:4658 minutes, 46 secondsright? The two columns we wanted, we multiplied them and then we gave it a name either by putting the name in at the beginning as a named argument or by
# 58:5458 minutes, 54 secondssaying alalias at the end. All right, but the issue is yeah what you brought up right that um this percentage is for
# 59:0359 minutes, 3 secondsthe whole school. Now, if the demographics of every class looks the same, right? If like the percentage is
# 59:1059 minutes, 10 secondsthe same for the 12th grade class, for the 11th, for the 10th, for the 9th, then it's probably fine, right? Maybe we're a little off. So, maybe this is
# 59:1859 minutes, 18 secondsjust an estimate, but we might be a little off, but probably not way off.
# 59:2359 minutes, 23 secondsBut there might be scenarios where we are way off. Can somebody give an example of a real world event that might happen that would cause something like this to be way off?
# 59:3459 minutes, 34 secondsYes.
# 59:4859 minutes, 48 secondsExactly. Great point. Right. If we have a lot of students dropping out, those students who are dropping out might disproportionately be uh poorer and
# 59:5659 minutes, 56 secondstherefore more likely to be eligible for free reduced price lunch. Right? So it might be that more of those people are in ninth in the earlier grades and as
# 1:00:041 hour, 4 secondsthey go into later grades um the people who are eligible are the ones who are more likely to drop out. Another example might be school closures, right? Often
# 1:00:131 hour, 13 secondswe see schools uh you know in poorer districts close and those students have to go to other schools, right? Which means in your ninth grade class then you
# 1:00:211 hour, 21 secondshave a huge addition of students many of whom might be uh more likely to be more
# 1:00:281 hour, 28 secondsel higher percent of eligibility for free reduced price lunch. Right? All kinds of reasons. Those are just like two examples. Um it's important to keep
# 1:00:361 hour, 36 secondsin mind when you do stuff like this that off the top of our heads like yeah this this seems perfectly reasonable but there might be times when this estimate
# 1:00:441 hour, 44 secondsmight not be right. This is something you will do a lot as a data scientist.
# 1:00:481 hour, 48 secondsMake estimates, make computations like this, but keep in mind the limitations uh when you do.
# 1:00:551 hour, 55 secondsAll right, we are good on time. All right, so we have an answer, right? We kind of like identified some outliers,
# 1:01:041 hour, 1 minute, 4 secondsright, in these schools, right? some of the larger schools that maybe have um interesting relations between uh like
# 1:01:121 hour, 1 minute, 12 secondsyou know more students eligible for free or reduced spice lunch but high application rates or vice versa but we
# 1:01:191 hour, 1 minute, 19 secondskind of want to we haven't really looked at admission and attendance and we haven't really defined typical patterns
# 1:01:261 hour, 1 minute, 26 secondsbut if we want to do that I want to first ask you a question of which plot is better right so again this is kind of
# 1:01:341 hour, 1 minute, 34 secondslike a recurring theme in our questions this uh for today. So I have two plots A and B, right? And in A this is like the
# 1:01:421 hour, 1 minute, 42 secondsversion that's like the version B from before, right? Where the size is number of 12th graders. But in B I've
# 1:01:481 hour, 1 minute, 48 secondssimplified it down to just a single line where on the X-axis now I have free
# 1:01:551 hour, 1 minute, 55 secondsreduced life free reduced lunch uh percentage percentile. Right? So this is
# 1:02:021 hour, 2 minutes, 2 secondsbasically this has all the the 0 to 25th percentile. This has 25th to 50th and so on. And on the y-axis I just have the
# 1:02:121 hour, 2 minutes, 12 secondsaverage application rate. Right? We kind of saw that lowest line that I was doing before. This is like an extreme uh version of that where I'm just doing it
# 1:02:201 hour, 2 minutes, 20 secondsbased on percentiles. So which of these two is better? Take a minute and discuss.
# 1:02:581 hour, 2 minutes, 58 secondsAll right, I'm going to close the voting in.
# 1:03:141 hour, 3 minutes, 14 secondsSo, please go ahead and vote if you have not already in five 4 3 2
# 1:03:231 hour, 3 minutes, 23 seconds1 01.
# 1:03:271 hour, 3 minutes, 27 secondsStill climbing, climbing, climbing, climbing. Okay, starting to slow down.
# 1:03:311 hour, 3 minutes, 31 secondsSo, I see more people saying A than B, but it's kind of close, right? So, 5347.
# 1:03:371 hour, 3 minutes, 37 secondsThis is really interesting, right? That people are split on which one of these two is better. And again, anytime you I ask you the question of which one is
# 1:03:451 hour, 3 minutes, 45 secondsbetter, you have to think about what does better mean? Better for what?
# 1:03:491 hour, 3 minutes, 49 secondsBetter in what way, right? And depending on the audience, we may want to show or not show every single data point. A has
# 1:03:581 hour, 3 minutes, 58 secondsa lot going on, right? If I'm like, you know, come if I like just walk in off, you know, uh, off the street and I look
# 1:04:051 hour, 4 minutes, 5 secondsat plot A, I'm like, wow, there's a lot going on in that graph, like, you know, I'm there's a ton of different schools.
# 1:04:111 hour, 4 minutes, 11 secondsThere's all these different sizes. I can spend a long time kind of eyeballing them. Do all the details really matter? Maybe, maybe not.
# 1:04:201 hour, 4 minutes, 20 secondsPlot B on the other hand is very very simple right it's really easy to see that hey for schools in the uh lowest
# 1:04:291 hour, 4 minutes, 29 secondsquartortile that is you know the bottom 25% of free reduced slice free free reduced price lunch percentage right
# 1:04:361 hour, 4 minutes, 36 secondsthat is the schools with the basically the schools with the most wellto-do students then the average application rate for those schools is really high
# 1:04:441 hour, 4 minutes, 44 secondswhereas as soon as you go even to the second quartile right 25th% percentile and up, we start to see a much lower
# 1:04:521 hour, 4 minutes, 52 secondsapplication rate. Right? Our application rate craters from 25% over here to 12
# 1:05:001 hour, 5 minutes1/2 or less percentage over here and even further down over here. Right? So, it's very easy to have a clean takeaway
# 1:05:081 hour, 5 minutes, 8 secondsfrom this, but that clean takeaway obscures the details of what's going on.
# 1:05:131 hour, 5 minutes, 13 secondsSo, there's a trade-off being made. I would kind of argue that these are like two extreme ends of a spectrum, right, between like lots of information and
# 1:05:221 hour, 5 minutes, 22 secondslike very simplified. Um there's certainly a place for each, right? It depends on who you're communicating to.
# 1:05:291 hour, 5 minutes, 29 secondsIf you're talking to um you know, another analyst at the UC admissions office, maybe they're going to want to see this version because they're wanting
# 1:05:361 hour, 5 minutes, 36 secondsthey might say, "Oh, yeah, I know that school, right? That one school up in the top right. Yeah, I went and visited that school. I had a call with someone there.
# 1:05:441 hour, 5 minutes, 44 secondsum I remember them. Whereas if you're talking with somebody who might not know as much about the the area and you want to like present a simple takeaway, you
# 1:05:531 hour, 5 minutes, 53 secondscan do this. There are also ways to go in between, right? You can take this plot on the left, make all the data points kind of fade it out and overlay
# 1:06:021 hour, 6 minutes, 2 secondsthe line on top, right? There are lots of things you can do in between these two extremes. Not just because they're extreme doesn't mean they're they're bad
# 1:06:101 hour, 6 minutes, 10 secondsor always never the right thing to do, but there's a huge spectrum of ways you can communicate with visualizations, which we'll talk a little bit more about next week and week after.
# 1:06:201 hour, 6 minutes, 20 secondsUm, okay. So, how would we generate this version of the graph?
# 1:06:281 hour, 6 minutes, 28 secondsWell, in order to generate this, we have to think about how our visualizations correspond to our data. Right? In the scatter plot we were looking at earlier,
# 1:06:361 hour, 6 minutes, 36 secondsI'm going to go back Here every single point corresponds to a school and in our data frame every single row corresponds to a school.
# 1:06:461 hour, 6 minutes, 46 secondsRight? And this is generally like a mental model that you want to have for your visualizations where every row in your data should correspond to one point
# 1:06:561 hour, 6 minutes, 56 secondsin a scatter plot or a line plot. And so that idea is called tidy data where each
# 1:07:031 hour, 7 minutes, 3 secondsrow represents one point. Right? If your data frame is set up like this, then it's called a tidy data frame. Um this
# 1:07:111 hour, 7 minutes, 11 secondsis a concept that comes from the world of R, right? Which is another programming language. Um our writing R code with tidy data. Something called
# 1:07:191 hour, 7 minutes, 19 secondstidyiverse actually looks very similar to polers. So in this case we have four points, right? We have one, two, three,
# 1:07:281 hour, 7 minutes, 28 secondsfour, right? And so we need four rows, right? Four data points in the plot, four rows in our data frame. What are
# 1:07:371 hour, 7 minutes, 37 secondsthose four rows? Well, for each one of those four, we need to know what the percentile of free reduced free reduced price lunch is. And we need to know the
# 1:07:451 hour, 7 minutes, 45 secondsaverage application rate for all the schools that fall within that 25% right there.
# 1:07:531 hour, 7 minutes, 53 secondsSo every point right is going to have these two things about it. The X and the Y, right? Free reduce price lunch percentile and average application rate.
# 1:08:031 hour, 8 minutes, 3 secondsAnd so we're going to need two columns, right? So we can see from this visualization that we're going to need four rows and two columns. Four rows
# 1:08:121 hour, 8 minutes, 12 secondsbecause we have four data points and two columns because we're showing two pieces of information about each data point.
# 1:08:201 hour, 8 minutes, 20 secondsIf we also were showing the size, right, a little dot with the size at each one, then maybe we would need a third column.
# 1:08:271 hour, 8 minutes, 27 secondsIf we had multiple lines, right, if we had two lines, then we wouldn't have four points, we would have eight, right?
# 1:08:351 hour, 8 minutes, 35 secondsAnd then we would need eight rows and we would need one more column to tell which line the point corresponds to. And so on and so on, right? So this is how we want
# 1:08:441 hour, 8 minutes, 44 secondsto think about the relationship between the visualization and the plot that goes with it.
# 1:08:501 hour, 8 minutes, 50 secondsSo this is the data that we actually need in order to work with our in order to generate this plot. So how we
# 1:08:591 hour, 8 minutes, 59 secondsactually go about generating it. Um before we do that a quick interlude on visualization code with Seabor. Again, I've kind of talked about this a little
# 1:09:071 hour, 9 minutes, 7 secondsbit so far, right? The way Seabour code looks is we write sns the plotting function, right? Scatter plot, line
# 1:09:151 hour, 9 minutes, 15 secondsplot, his plot, reg plot, whatever. And then the first argument is always going to be your data frame. And then the next few arguments are going to be like what
# 1:09:231 hour, 9 minutes, 23 secondsis the x, what is the y, um what is the size, what is the color, and so on. And then at the end, you give it all the
# 1:09:321 hour, 9 minutes, 32 secondsformatting arguments. This is where it's great to like just know how to look it up. Ask a large language model. Um, these are things you want to like think
# 1:09:391 hour, 9 minutes, 39 secondscarefully about. These are things you want to like think about and then ask or or look up how to actually rate. These are the things that I've been doing this
# 1:09:481 hour, 9 minutes, 48 secondsfor, you know, more than 10 years and I never remember how.
# 1:09:521 hour, 9 minutes, 52 secondsSo, we've done all these operations so far, right? We've talked about how to view, uh, select, add columns, filter,
# 1:10:001 hour, 10 minutessort. uh we talked about how to calculate summary statistics and now we've even learned how to visualize one-dimensional data with box plots and
# 1:10:091 hour, 10 minutes, 9 secondshistograms and visualize 2D data with scatter plots and line plots. So what we're going to talk about at the in the last few minutes of today and spend a
# 1:10:171 hour, 10 minutes, 17 secondsgood chunk of next week on is grouping by a variable and then doing something within each group. usually aggregation
# 1:10:251 hour, 10 minutes, 25 secondsbut sometimes other stuff and the way this is going to look in English is for each unique value of some column do some
# 1:10:351 hour, 10 minutes, 35 secondscalculation and again a little bit of data science wisdom the vast majority of the EDA work
# 1:10:421 hour, 10 minutes, 42 secondsthat you will do is grouping right it's answering these questions for each group what does this look like then maybe
# 1:10:501 hour, 10 minutes, 50 secondscalculate the differences across these groups look at this across these different groups then slice the data a different way look at a different set of
# 1:10:571 hour, 10 minutes, 57 secondsgroups and make this uh same calculation or a different calculation. So knowing how to do groups thinking about it
# 1:11:051 hour, 11 minutes, 5 secondsintuitively understanding the the basics of the writing code about it is a critical operation in being a good data scientist.
# 1:11:131 hour, 11 minutes, 13 secondsSo how do we actually uh think about grouping? Again, we're going to talk about the conceptual part today and then get into the code uh next week.
# 1:11:251 hour, 11 minutes, 25 secondsSo, the way grouping works is using something called the split apply combine paradigm, right? Which is basically just like a fancy way of saying we're going to split up our data by groups, right?
# 1:11:371 hour, 11 minutes, 37 secondsIn this case, let's suppose we want to say for each city, we want to count the number of rows. For each unique value of city, count the
# 1:11:451 hour, 11 minutes, 45 secondsnumber of rows. So we're going to do is we're going to split up our data into one subgroup per city, right? So we take
# 1:11:541 hour, 11 minutes, 54 secondsall of our data, find all the places where city is A, B and C. This is like a simplified version with three cities A, B, and C. So step one, split it up by
# 1:12:031 hour, 12 minutes, 3 secondscity. Take all the rows where city is A, all the rows where city is B, all the rows where city is C.
# 1:12:111 hour, 12 minutes, 11 secondsStep two is apply. So do some operation on each of these groups and then step three is combine the results back.
# 1:12:201 hour, 12 minutes, 20 secondsRight? So this fundamental operation, this fundamental series of steps is how every single group we're going to talk about in this class is going to work.
# 1:12:291 hour, 12 minutes, 29 secondsRight? The group by operation that you learned in SQL, the grouping that you did in data 8, all of this works in the
# 1:12:361 hour, 12 minutes, 36 secondssame basic way, right? We split by each and have one little subgroup for each of our uh groups right subframe and then we
# 1:12:451 hour, 12 minutes, 45 secondsdo our operation our application in this case count the number of rows and then step three is to combine them back. So
# 1:12:531 hour, 12 minutes, 53 secondsthis step two this application can be as complex as we want right we can say find the average of um the
# 1:13:031 hour, 13 minutes, 3 secondsfind the average number of people who uh applied minus the average number of people who were admitted right or we can
# 1:13:101 hour, 13 minutes, 10 secondsdo any number of operations in the supply step right and that might give us a sense of like what's the difference between application admission right but
# 1:13:171 hour, 13 minutes, 17 secondsthis paradigm thinking about it is first we split up our data then we apply some operation and then we combine the
# 1:13:241 hour, 13 minutes, 24 secondsresults back is the core of what we're going to be working with. Right? So in this case we've answered the question by
# 1:13:311 hour, 13 minutes, 31 secondscounting the number of rows. Right? A has city A has three rows, city B has three rows. City C has only two. Right?
# 1:13:401 hour, 13 minutes, 40 secondsUm oops did not mean to have the code there. Ignore the code. This is uh pandas which we're not uh covering. What if we
# 1:13:481 hour, 13 minutes, 48 secondswant to compute the mean? Right? Well, if you want to compute the mean number of uh people who enroll in each city,
# 1:13:561 hour, 13 minutes, 56 secondsthen we say okay, do the same split. And now we have city A has 25, 30 and 35,
# 1:14:041 hour, 14 minutes, 4 secondsright? One school with 25, one school with 30, one school with 35 and so on and so on. And then the thing we apply is compute the average of the enrolled column.
# 1:14:151 hour, 14 minutes, 15 secondsRight? In this case, the average is 30.
# 1:14:171 hour, 14 minutes, 17 secondsIn this case, the average is 40. In this case, average is 25. and then combine the results back. Right? So that conceptual process right this
# 1:14:251 hour, 14 minutes, 25 secondsdescription of for each unique value of city compute the mean number of students enrolled across its schools. Again we do
# 1:14:331 hour, 14 minutes, 33 secondsit with the same uh apply split apply combine paradigm. So next week uh you will get a chance to kind of work with
# 1:14:421 hour, 14 minutes, 42 secondsthis in in code and also see how we can use this to go deeper into our analysis of this data set. One thing I want to
# 1:14:501 hour, 14 minutes, 50 secondspoint out before we all leave is we have been spending like three lectures just on this question. We're going to continue to spend two more. This is not
# 1:14:591 hour, 14 minutes, 59 secondsuncommon. I've worked on projects where we spent entire months just doing exploratory data analysis on one data set. So don't like feel weird that wow
# 1:15:071 hour, 15 minutes, 7 secondswe spent so long on this data. This is exactly how real data science works. All right. Uh Jeremy will be teaching you all next week. I'll see you all in two
# 1:15:151 hour, 15 minutes, 15 secondsweeks. I will have office hours today upstairs in 210 Wheeler.
